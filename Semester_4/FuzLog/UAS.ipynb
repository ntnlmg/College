# %% [markdown]
# UAS Ori

# %%
from PIL import Image
import numpy as np
from scipy.spatial.distance import euclidean

def findMiddlePoint(point1, point2, point3):
    x_avg = sum([point[0] for point in [point1, point2, point3]]) / 3
    y_avg = sum([point[1] for point in [point1, point2, point3]]) / 3
    return [x_avg, y_avg]

def setRGBtoMaxValue(fcm_image):
    width, height = fcm_image.size
    for y in range(height):
        for x in range(width):
            r, g, b = fcm_image.getpixel((x, y))
            if ((r > g and r > b) or (r == g)):
                fcm_image.putpixel((x, y), (255, 0, 0))
            elif ((g > r and g > b) or (g == b)):
                fcm_image.putpixel((x, y), (0, 255, 0))
            elif ((b > r and b > g) or (b == r)):
                fcm_image.putpixel((x, y), (0, 0, 255))

            r, g, b = fcm_image.getpixel((x, y))
            # print(f"Pixel at ({x}, {y}): R={r}, G={g}, B={b}")
    return fcm_image

def setNewImage(fcm_image, cluster_r, cluster_g, cluster_b):
    R = []
    G = []
    B = []
    width, height = fcm_image.size
    for y in range(height):
        for x in range(width):
            this_point = [x, y]
            r, g, b = fcm_image.getpixel((x, y))
            if (fcm_image.getpixel((x, y)) != (0, 0, 0) and fcm_image.getpixel((x, y)) != (255, 165, 0)):
                fcm_image.putpixel((x, y), (255, 255, 255))

    middle_point = findMiddlePoint(cluster_r, cluster_g, cluster_b)
    print((int)(middle_point[0]), (int)(middle_point[1]))
    for y in range(height):
        for x in range(width):
            this_point = [x, y]
            distance_from_r = euclidean(this_point, cluster_r)
            distance_from_g = euclidean(this_point, cluster_g)
            distance_from_b = euclidean(this_point, cluster_b)
            distance_from_r_to_center = euclidean(this_point, cluster_r)
            distance_from_g_to_center = euclidean(middle_point, cluster_g)
            distance_from_b_to_center = euclidean(middle_point, cluster_b)
            distance_to_r = int(euclidean(this_point, cluster_r)) * 8 + 50
            distance_to_g = int(euclidean(this_point, cluster_g)) * 8 + 50
            distance_to_b = int(euclidean(this_point, cluster_b)) * 8 + 50
            # print(distance_to_r, distance_to_g, distance_to_b)

            r, g, b = fcm_image.getpixel((x, y))
            if (fcm_image.getpixel((x, y)) == (255, 255, 255)):
                if (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_r):
                    fcm_image.putpixel((x, y), (255, 0, 0))
                elif (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_g):
                    fcm_image.putpixel((x, y), (0, 255, 0))
                elif (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_b):
                    fcm_image.putpixel((x, y), (0, 0, 255))
            # REINBOW
            # if (fcm_image.getpixel((x, y)) == (255, 255, 255)):
            #     if (distance_from_r < distance_from_g and distance_from_r < distance_from_b):
            #         fcm_image.putpixel((x, y), (distance_to_r, distance_to_g, distance_to_b))
            #         # print(int(distance_from_r_to_center / 255 * 255))
            #     elif (distance_from_g < distance_from_r and distance_from_g < distance_from_b):
            #         fcm_image.putpixel((x, y), (distance_to_r, distance_to_g, distance_to_b))
            #     elif (distance_from_b < distance_from_r and distance_from_b < distance_from_g):
            #         fcm_image.putpixel((x, y), (distance_to_r, distance_to_g, distance_to_b))

    
    fcm_image.putpixel(((int)(middle_point[0]), (int)(middle_point[1])), (255, 255, 255))
    # print(len(R), len(G), len(B))
    fcm_image.putpixel((int(cluster_r[0]), int(cluster_r[1])), (255, 0, 255))
    fcm_image.putpixel((int(cluster_g[0]), int(cluster_g[1])), (255, 255, 0))
    fcm_image.putpixel((int(cluster_b[0]), int(cluster_b[1])), (0, 255, 255))

    return fcm_image

def generateBitmap(width, height):

    image = Image.new("RGB", (width, height), (0, 0, 0))
    for y in range(width):
        for x in range(height):
            randnum = np.random.randint(1, 101)
            # print(randnum)
            if (randnum >= 1 and randnum <= 5 and y < height / 3 and x < width / 3):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 6 and randnum <= 9):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 10 and randnum <= 30 and y > height / 1.3 and x > width / 1.3):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 31 and randnum <= 100):
                image.putpixel((x, y), (0, 0, 0))

    return image

def FCM(image, iteration):
    def arrSum(arr1, arr2, arr3):
        random_sum = []
        for i in range(len(arr1)):
            random_sum.append(arr1[i] + arr2[i] + arr3[i])
        return random_sum

    def arrSum2(arr1, arr2):
        random_sum = []
        for i in range(len(arr1)):
            random_sum.append(arr1[i] + arr2[i])
        return random_sum

    def arrMultiply(arr1, arr2):
        arr = []
        for i in range(len(arr1)):
            arr.append(arr1[i] * arr2[i])
        return arr

    def setMyu(random_arr, random_sum):
        myu = []
        for i in range(len(random_arr)):
            myu.append(random_arr[i] / random_sum[i])
        return myu

    def sumArr(arr):
        num = 0
        for i in range(len(arr)):
            num += arr[i]
        return num

    def myuSquared(arr):
        for i in range(len(arr)):
            arr[i] *= arr[i]
        return arr  

    def getL(arr1, arr2, arr_sum, arr_squared):
        arr = []
        for i in range(len(arr1)):
            arr.append(((arr1[i] - arr_sum[0])**2 + (arr2[i] - arr_sum[1])**2) * arr_squared[i])
        return arr

    def onePerL(arr1, arr2):
        arr = []
        for i in range(len(arr1)):
            arr.append(1 / (arr1[i] / arr2[i]))
        return arr

    print(image)
    X = []
    Y = []
    width, height = fcm_image.size
    for y in range(height):
            for x in range(width):
                if (fcm_image.getpixel((x, y)) != (0, 0, 0)):
                    X.append(x)
                    Y.append(y)
                # print(f"Pixel at ({x}, {y}): X={r}, Y={g}, B={b}")
    print(X)
    print(Y)
    randnum_r = np.random.rand(len(X))
    randnum_g = np.random.rand(len(X))
    randnum_b = np.random.rand(len(X))

    p_total = []
    error_log = []
    randnum_sum = arrSum(randnum_r, randnum_g, randnum_b)
    myu_r = setMyu(randnum_r, randnum_sum) 
    myu_g = setMyu(randnum_g, randnum_sum)
    myu_b = setMyu(randnum_b, randnum_sum)
    # myu_sum = arrSum(myu_r, myu_g, myu_b)

    for i in range(iteration):
        # print(i, myu_r, myu_g, myu_g)
        myu_r_squared = myuSquared(myu_r) 
        myu_g_squared = myuSquared(myu_g)
        myu_b_squared = myuSquared(myu_b)

        R_x = arrMultiply(myu_r_squared, X) 
        R_y = arrMultiply(myu_r_squared, Y)
        G_x = arrMultiply(myu_g_squared, X)
        G_y = arrMultiply(myu_g_squared, Y)
        B_x = arrMultiply(myu_b_squared, X)
        B_y = arrMultiply(myu_b_squared, Y)

        myu_R_sum = sumArr(myu_r_squared) 
        R_x_sum = sumArr(R_x)
        R_y_sum = sumArr(R_y)
        myu_G_sum = sumArr(myu_g_squared)
        G_x_sum = sumArr(G_x)
        G_y_sum = sumArr(G_y)
        myu_B_sum = sumArr(myu_b_squared)
        B_x_sum = sumArr(B_x)
        B_y_sum = sumArr(B_y)

        cluster_r = []
        cluster_r.append(R_x_sum / myu_R_sum)
        cluster_r.append(R_y_sum / myu_R_sum)
        cluster_g = []
        cluster_g.append(G_x_sum / myu_G_sum)
        cluster_g.append(G_y_sum / myu_G_sum)
        cluster_b = []
        cluster_b.append(B_x_sum / myu_B_sum)
        cluster_b.append(B_y_sum / myu_B_sum)

        L_r = getL(X, Y, cluster_r, myu_r_squared)
        L_g = getL(X, Y, cluster_g, myu_g_squared)
        L_b = getL(X, Y, cluster_b, myu_b_squared)
        L_sum = sumArr(arrSum(L_r, L_g, L_b))

        one_L_r = onePerL(L_r, myu_r_squared)
        one_L_g = onePerL(L_g, myu_g_squared)
        one_L_b = onePerL(L_b, myu_b_squared)
        one_L_sum = arrSum(one_L_r, one_L_g, one_L_b)

        myu_r = setMyu(one_L_r, one_L_sum)
        myu_g = setMyu(one_L_g, one_L_sum)
        myu_b = setMyu(one_L_b, one_L_sum)

        p_total.append(L_sum)
        fcm_image.putpixel((int(cluster_r[0]), int(cluster_r[1])), (255, 165, 0))
        fcm_image.putpixel((int(cluster_g[0]), int(cluster_g[1])), (255, 165, 0))
        fcm_image.putpixel((int(cluster_b[0]), int(cluster_b[1])), (255, 165, 0))

    for i in range(1, len(p_total)):
        error_log.append(p_total[i-1] - p_total[i])

    return p_total, error_log, cluster_r, cluster_g, cluster_b

fcm_image = Image.open('fcm7.png')
x, y = fcm_image.size
# x = 50 
# y = 50
# fcm_image = generateBitmap(x, y)
fcm_image = fcm_image.convert('RGB')
# print(fcm_image)
fcm_image.save("old_fcm.png")

# np.random.seed(1)

p_total, error_log, cluster_r, cluster_g, cluster_b = FCM(fcm_image, 30)

cluster_r[0] = int(cluster_r[0])
cluster_r[1] = int(cluster_r[1])
cluster_g[0] = int(cluster_g[0])
cluster_g[1] = int(cluster_g[1])
cluster_b[0] = int(cluster_b[0])
cluster_b[1] = int(cluster_b[1])

print("Last p value : ", p_total[len(p_total)-1])
print("Last error value : ", error_log[len(error_log)-1])
print("Cluster RED at : ", cluster_r)
print("Cluster GREEN at : ", cluster_g)
print("Cluster BLUE at : ", cluster_b)

fcm_image = setNewImage(fcm_image, cluster_r, cluster_g, cluster_b)
fcm_image.save("new_fcm.png")
# fcm_image.show()


# print(cluster_x, cluster_y)

# ((R - cluster_x[0])^2 + (G- cluster_x[1])^2 + (B - cluster_x[2])^2) * myu_x_squared
# print(((R[0] - cluster_x[0])**2 + (G[0] - cluster_x[1])**2 + (B[0] - cluster_x[2])**2) * myu_x_squared[0])
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x2BF3C2B19A0>
# [58, 69, 62, 65, 70, 61, 64, 56, 61, 65, 72, 76, 68, 62, 66, 73, 74, 75, 56, 64, 75, 83, 66, 82, 59, 72, 76, 55, 58, 64, 66, 53, 58, 65, 85, 86, 44, 49, 57, 49, 52, 61, 67, 73, 80, 45, 50, 51, 57, 58, 67, 75, 77, 45, 61, 64, 65, 70, 72, 77, 47, 82, 49, 58, 63, 76, 78, 82, 88, 57, 65, 79, 83, 85, 49, 56, 62, 66, 67, 69, 73, 45, 49, 57, 69, 77, 81, 87, 92, 53, 64, 67, 81, 86, 87, 48, 62, 63, 68, 77, 80, 86, 92, 56, 74, 48, 53, 57, 60, 62, 64, 72, 75, 77, 80, 87, 53, 61, 66, 77, 87, 90, 14, 56, 75, 80, 82, 45, 79, 80, 86, 89, 44, 57, 58, 68, 71, 79, 81, 83, 89, 48, 52, 65, 74, 83, 47, 54, 56, 59, 54, 58, 69, 76, 87, 88, 91, 12, 48, 64, 66, 86, 94, 5, 6, 11, 13, 52, 61, 69, 86, 6, 16, 50, 53, 59, 75, 79, 81, 86, 91, 11, 59, 71, 81, 85, 92, 8, 11, 55, 67, 73, 97, 7, 10, 12, 46, 53, 65, 71, 77, 91, 9, 11, 53, 84, 9, 10, 13, 15, 59, 60, 61, 67, 88, 90, 7, 10, 11, 12, 17, 52, 54, 55, 57, 59, 67, 76, 5, 7, 8, 12, 13, 15, 68, 71, 82, 89, 90, 5, 8, 9, 12, 14, 16, 78, 79, 88, 4, 8, 10, 11, 12, 13, 14, 15, 74, 85, 88, 89, 7, 8, 10, 12, 14, 17, 62, 65, 8, 12, 13, 73, 78, 6, 9, 10, 11, 12, 13, 83, 8, 9, 10, 11, 68, 10, 11, 8, 9, 10, 11, 12, 13, 6, 7, 8, 10, 11, 14, 10, 11, 13, 7, 10, 12, 13, 10, 11, 8, 9, 10, 11, 12, 15, 5, 7, 9, 10, 12, 15, 18, 6, 7, 8, 9, 10, 12, 6, 7, 8, 10, 11, 17, 7, 8, 10, 11, 14, 15, 8, 10, 9, 10, 13, 15, 6, 8, 10, 11, 12, 15, 8, 11, 5, 8, 10, 12, 8, 9, 11, 12, 14, 15, 7, 10, 13, 6, 7, 9, 10, 14, 8, 9, 10, 12, 15, 4, 8, 10, 12, 4, 10, 12, 14, 9, 11, 14, 80, 6, 9, 79, 81, 7, 74, 78, 4, 67, 73, 75, 76, 77, 80, 65, 71, 73, 74, 77, 79, 81, 83, 85, 65, 69, 74, 76, 77, 80, 84, 67, 68, 69, 74, 75, 77, 79, 81, 82, 83, 88, 63, 67, 70, 71, 72, 73, 75, 76, 77, 78, 81, 82, 85, 89, 61, 69, 70, 71, 73, 74, 75, 77, 78, 81, 82, 84, 86, 87, 88, 63, 64, 65, 70, 71, 74, 76, 79, 80, 81, 82, 83, 84, 85, 66, 67, 68, 69, 70, 72, 74, 76, 78, 79, 82, 83, 86, 90, 58, 63, 64, 66, 67, 68, 69, 70, 74, 75, 77, 78, 79, 80, 81, 83, 84, 85, 86, 89, 64, 68, 72, 73, 74, 75, 77, 78, 79, 82, 83, 85, 86, 87, 64, 65, 66, 71, 72, 73, 74, 79, 81, 82, 83, 84, 85, 87, 67, 68, 70, 71, 72, 73, 74, 75, 77, 78, 79, 80, 81, 82, 84, 86, 89, 67, 68, 69, 71, 72, 73, 75, 76, 77, 79, 80, 83, 88, 64, 68, 69, 71, 73, 74, 75, 78, 79, 81, 86, 87, 70, 73, 74, 78, 81, 84, 87, 71, 75, 81, 82, 84, 76, 81, 74, 76, 81, 77]
# [2, 3, 4, 4, 4, 5, 5, 6, 6, 6, 6, 6, 7, 8, 8, 8, 8, 8, 10, 10, 10, 10, 11, 11, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 14, 15, 15, 15, 16, 16, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 19, 19, 20, 20, 20, 20, 20, 20, 20, 21, 21, 21, 21, 21, 22, 22, 22, 22, 22, 22, 22, 23, 23, 23, 23, 23, 23, 23, 23, 24, 24, 24, 24, 24, 24, 25, 25, 25, 25, 25, 25, 25, 25, 26, 26, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 28, 28, 28, 28, 28, 28, 29, 29, 29, 29, 29, 30, 30, 30, 30, 30, 31, 31, 31, 31, 31, 31, 31, 31, 31, 32, 32, 32, 32, 32, 33, 33, 33, 33, 34, 34, 34, 34, 34, 34, 34, 35, 35, 35, 35, 35, 35, 36, 36, 36, 36, 36, 36, 36, 36, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 38, 38, 38, 38, 38, 38, 39, 39, 39, 39, 39, 39, 40, 40, 40, 40, 40, 40, 40, 40, 40, 41, 41, 41, 41, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 45, 45, 45, 45, 45, 45, 45, 45, 45, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 47, 47, 47, 47, 47, 47, 47, 47, 48, 48, 48, 48, 48, 49, 49, 49, 49, 49, 49, 49, 50, 50, 50, 50, 50, 51, 51, 52, 52, 52, 52, 52, 52, 53, 53, 53, 53, 53, 53, 54, 54, 54, 55, 55, 55, 55, 56, 56, 57, 57, 57, 57, 57, 57, 58, 58, 58, 58, 58, 58, 58, 59, 59, 59, 59, 59, 59, 60, 60, 60, 60, 60, 60, 61, 61, 61, 61, 61, 61, 62, 62, 63, 63, 63, 63, 64, 64, 64, 64, 64, 64, 65, 65, 66, 66, 66, 66, 67, 67, 67, 67, 67, 67, 68, 68, 68, 69, 69, 69, 69, 69, 70, 70, 70, 70, 70, 72, 73, 73, 73, 74, 74, 74, 74, 75, 75, 75, 75, 76, 76, 76, 76, 77, 77, 77, 78, 78, 78, 78, 78, 78, 78, 79, 79, 79, 79, 79, 79, 79, 79, 79, 80, 80, 80, 80, 80, 80, 80, 81, 81, 81, 81, 81, 81, 81, 81, 81, 81, 81, 82, 82, 82, 82, 82, 82, 82, 82, 82, 82, 82, 82, 82, 82, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 84, 84, 84, 84, 84, 84, 84, 84, 84, 84, 84, 84, 84, 84, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 91, 91, 91, 91, 91, 91, 91, 91, 91, 91, 91, 91, 92, 92, 92, 92, 92, 92, 92, 93, 93, 94, 94, 94, 95, 95, 96, 96, 96, 97]
# Last p value :  87509.64080814148
# Last error value :  1.7462298274040222e-10
# Cluster RED at :  [69, 25]
# Cluster GREEN at :  [10, 55]
# Cluster BLUE at :  [76, 85]
# 51 55

# %% [markdown]
# UAS New

# %%
from PIL import Image
import numpy as np
from scipy.spatial.distance import euclidean

def setRGBtoMaxValue(fcm_image):
    width, height = fcm_image.size
    for y in range(height):
        for x in range(width):
            r, g, b = fcm_image.getpixel((x, y))
            if ((r > g and r > b) or (r == g)):
                fcm_image.putpixel((x, y), (255, 0, 0))
            elif ((g > r and g > b) or (g == b)):
                fcm_image.putpixel((x, y), (0, 255, 0))
            elif ((b > r and b > g) or (b == r)):
                fcm_image.putpixel((x, y), (0, 0, 255))

            r, g, b = fcm_image.getpixel((x, y))
            # print(f"Pixel at ({x}, {y}): R={r}, G={g}, B={b}")
    return fcm_image

def generateBitmap(width, height):
    image = Image.new("RGB", (width, height), (0, 0, 0))
    for y in range(width):
        for x in range(height):
            randnum = np.random.randint(1, 101)
            if (randnum >= 1 and randnum <= 5 and y < height / 3 and x < width / 3):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 6 and randnum <= 9):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 10 and randnum <= 30 and y > height / 1.3 and x > width / 1.3):
                image.putpixel((x, y), (255, 255, 255))
            elif (randnum >= 31 and randnum <= 100):
                image.putpixel((x, y), (0, 0, 0))

    return image

# Used
def findMiddlePoint(point1, point2, point3):
    x_avg = sum([point[0] for point in [point1, point2, point3]]) / 3
    y_avg = sum([point[1] for point in [point1, point2, point3]]) / 3
    return [x_avg, y_avg]

def setNewImage(fcm_image, cluster_r, cluster_g, cluster_b):
    width, height = fcm_image.size
    for y in range(height):
        for x in range(width):
            this_point = [x, y]
            if (fcm_image.getpixel((x, y)) != (0, 0, 0) and fcm_image.getpixel((x, y)) != (255, 165, 0)):
                fcm_image.putpixel((x, y), (255, 255, 255))

    for y in range(height):
        for x in range(width):
            this_point = [x, y]
            distance_to_r = int(euclidean(this_point, cluster_r))
            distance_to_g = int(euclidean(this_point, cluster_g))
            distance_to_b = int(euclidean(this_point, cluster_b))
            if (fcm_image.getpixel((x, y)) == (255, 255, 255)):
                if (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_r):
                    fcm_image.putpixel((x, y), (255, 0, 0))
                elif (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_g):
                    fcm_image.putpixel((x, y), (0, 255, 0))
                elif (min(distance_to_r, distance_to_g, distance_to_b) == distance_to_b):
                    fcm_image.putpixel((x, y), (0, 0, 255))
    
    middle_point = findMiddlePoint(cluster_r, cluster_g, cluster_b)
    # print((int)(middle_point[0]), (int)(middle_point[1]))
    fcm_image.putpixel(((int)(middle_point[0]), (int)(middle_point[1])), (255, 255, 255))
    fcm_image.putpixel((int(cluster_r[0]), int(cluster_r[1])), (255, 0, 255))
    fcm_image.putpixel((int(cluster_g[0]), int(cluster_g[1])), (255, 255, 0))
    fcm_image.putpixel((int(cluster_b[0]), int(cluster_b[1])), (0, 255, 255))

    return fcm_image

def FCM(image, iteration, error): 
    def arrSum(arr1, arr2, arr3):
        random_sum = []
        for i in range(len(arr1)):
            random_sum.append(arr1[i] + arr2[i] + arr3[i])
        return random_sum

    def arrMultiply(arr1, arr2):
        arr = []
        for i in range(len(arr1)):
            arr.append(arr1[i] * arr2[i])
        return arr

    def setMyu(random_arr, random_sum):
        myu = []
        for i in range(len(random_arr)):
            myu.append(random_arr[i] / random_sum[i])
        return myu

    def sumArr(arr):
        num = 0
        for i in range(len(arr)):
            num += arr[i]
        return num

    def myuSquared(arr):
        for i in range(len(arr)):
            arr[i] *= arr[i]
        return arr

    def getL(arr1, arr2, arr_sum, arr_squared):
        arr = []
        for i in range(len(arr1)):
            arr.append(((arr1[i] - arr_sum[0])**2 + (arr2[i] - arr_sum[1])**2) * arr_squared[i])
        return arr

    def onePerL(arr1, arr2):
        arr = []
        for i in range(len(arr1)):
            arr.append(1 / (arr1[i] / arr2[i]))
        return arr

    print(image)
    X = []
    Y = []
    width, height = fcm_image.size
    for y in range(height):
            for x in range(width):
                if (fcm_image.getpixel((x, y)) != (0, 0, 0)):
                    X.append(x)
                    Y.append(y)
                # print(f"Pixel at ({x}, {y}): X={r}, Y={g}, B={b}")

    randnum_r = np.random.rand(len(X))
    randnum_g = np.random.rand(len(X))
    randnum_b = np.random.rand(len(X))

    p_total = [0]
    error_log = []
    randnum_sum = arrSum(randnum_r, randnum_g, randnum_b)
    myu_r = setMyu(randnum_r, randnum_sum) # menghitung µ rgb dengan fungsi setMyu (nilai rand / jumlah total nilai rand)
    myu_g = setMyu(randnum_g, randnum_sum)
    myu_b = setMyu(randnum_b, randnum_sum)
    # myu_sum = arrSum(myu_r, myu_g, myu_b)

    for i in range(iteration):
        myu_r_squared = myuSquared(myu_r) # menghitung µ² rgb dengan fungsi myuSquare(µ*µ)
        myu_g_squared = myuSquared(myu_g)
        myu_b_squared = myuSquared(myu_b)

        R_x = arrMultiply(myu_r_squared, X) # mengalikan µ² dengan nilai X, Y dengan fungsi arrMultiply(µ²* X dan µ² * Y)
        R_y = arrMultiply(myu_r_squared, Y)
        G_x = arrMultiply(myu_g_squared, X)
        G_y = arrMultiply(myu_g_squared, Y)
        B_x = arrMultiply(myu_b_squared, X)
        B_y = arrMultiply(myu_b_squared, Y)

        myu_R_sum = sumArr(myu_r_squared) # menambahkan/menjumlahkan semua µ², µ²* X dan µ² * Y  dengan fungsi sumArr
        R_x_sum = sumArr(R_x)
        R_y_sum = sumArr(R_y)
        myu_G_sum = sumArr(myu_g_squared)
        G_x_sum = sumArr(G_x)
        G_y_sum = sumArr(G_y)
        myu_B_sum = sumArr(myu_b_squared)
        B_x_sum = sumArr(B_x)
        B_y_sum = sumArr(B_y)

        # menghitung clusternya dengan hasil penjumlahan µ²* X dan µ²* Y / hasil penjumlahan µ²
        cluster_r = []
        cluster_r.append(R_x_sum / myu_R_sum) 
        cluster_r.append(R_y_sum / myu_R_sum)
        cluster_g = []
        cluster_g.append(G_x_sum / myu_G_sum)
        cluster_g.append(G_y_sum / myu_G_sum)
        cluster_b = []
        cluster_b.append(B_x_sum / myu_B_sum)
        cluster_b.append(B_y_sum / myu_B_sum)
        
        # menghitung L dengan ((X-cluster)^2 + (Y-cluster)^2)*µ²
        L_r = getL(X, Y, cluster_r, myu_r_squared)
        L_g = getL(X, Y, cluster_g, myu_g_squared)
        L_b = getL(X, Y, cluster_b, myu_b_squared)
        L_sum = sumArr(arrSum(L_r, L_g, L_b))

        one_L_r = onePerL(L_r, myu_r_squared)
        one_L_g = onePerL(L_g, myu_g_squared)
        one_L_b = onePerL(L_b, myu_b_squared)
        one_L_sum = arrSum(one_L_r, one_L_g, one_L_b)

        myu_r = setMyu(one_L_r, one_L_sum)
        myu_g = setMyu(one_L_g, one_L_sum)
        myu_b = setMyu(one_L_b, one_L_sum)

        p_total.append(L_sum)
        fcm_image.putpixel((int(cluster_r[0]), int(cluster_r[1])), (255, 165, 0))
        fcm_image.putpixel((int(cluster_g[0]), int(cluster_g[1])), (255, 165, 0))
        fcm_image.putpixel((int(cluster_b[0]), int(cluster_b[1])), (255, 165, 0))

        error_log.append(abs(p_total[i] - p_total[i+1]))
        if (error_log[i] < error):
            print(f"Stop at {i} iteration")
            break
        
    cluster_r[0] = int(cluster_r[0])
    cluster_r[1] = int(cluster_r[1])
    cluster_g[0] = int(cluster_g[0])
    cluster_g[1] = int(cluster_g[1])
    cluster_b[0] = int(cluster_b[0])
    cluster_b[1] = int(cluster_b[1])

    return p_total, error_log, cluster_r, cluster_g, cluster_b

# x = 50 
# y = 50
# fcm_image = generateBitmap(x, y)
# np.random.seed(1)
fcm_image = Image.open('fcm7.png')
x, y = fcm_image.size
fcm_image = fcm_image.convert('RGB')
fcm_image.save("old_fcm.png")

p_total, error_log, cluster_r, cluster_g, cluster_b = FCM(fcm_image, 50, 0.03)

print("p value : ", p_total)
print("Last p value : ", p_total[len(p_total)-1])
print("error value : ", error_log)
print("Last error value : ", error_log[len(error_log)-1])
print("Cluster RED at : ", cluster_r)
print("Cluster GREEN at : ", cluster_g)
print("Cluster BLUE at : ", cluster_b)

fcm_image = setNewImage(fcm_image, cluster_r, cluster_g, cluster_b)
fcm_image.save("new_fcm.png")
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x27355C12310>
# Stop at 12 iteration
# p value :  [0, 405482.5299871151, 313661.5578237894, 309800.0018983723, 291507.05708932015, 239116.3798742692, 174014.231244797, 97560.38349527618, 87872.2196949468, 87528.00588591158, 87510.81507236756, 87509.72865557729, 87509.6479761353, 87509.64141866616]
# Last p value :  87509.64141866616
# error value :  [405482.5299871151, 91820.9721633257, 3861.5559254171094, 18292.944809052162, 52390.677215050964, 65102.14862947218, 76453.84774952082, 9688.163800329377, 344.2138090352237, 17.190813544017146, 1.0864167902764166, 0.08067944199137855, 0.006557469139806926]
# Last error value :  0.006557469139806926
# Cluster RED at :  [10, 55]
# Cluster GREEN at :  [69, 25]
# Cluster BLUE at :  [76, 85]
